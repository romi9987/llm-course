# %%
from openai import OpenAI

# %%
client = OpenAI()

# %%
response = client.chat.completions.create(
  model="gpt-4o-mini",
  store=True,
  messages=[
    {"role": "user", "content": "is it too late to join the course?"}
  ]
)

# %%
response.choices[0].message.content
# Out:
# "Whether it's too late to join a course depends on the specific course and its enrollment policies. Many courses have specific deadlines for enrollment, which can vary widely. I recommend checking the course’s official website or contacting the course administrator for information on enrollment deadlines and availability. If you provide more details about the course, I might be able to give you more specific advice!"
